# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanyok/Matplotlib_Challenge/blob/main/Back_To_The_Moon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=42)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_moons, y_moons, random_state=42)

# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a Keras Sequential model and add more than one Dense hidden layer
model = tf.keras.models.Sequential()

# network
# 2 inputs
# 1st hidden layer - 5 neurons
# 2nd hidden layer - 5 neurons
# 1 output

# add the first layer w/ first hidden layer
model.add(tf.keras.layers.Dense(units = 5, activation = 'relu', input_dim=2))

# add a second hidden layer of neutrons 
model.add(tf.keras.layers.Dense(units = 5, activation = 'relu'))

# add output layer
model.add(tf.keras.layers.Dense(units=1, activation = 'sigmoid'))

# Check the structure of the Sequential model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# ...
# Total params: 51
# Trainable params: 51
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model and train over more than 100 epochs
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

fittedModel = model.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 1s 3ms/step - loss: 0.6906 - accuracy: 0.4973
# Epoch 2/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6602 - accuracy: 0.7747
# Epoch 3/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6310 - accuracy: 0.8307
# Epoch 4/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6002 - accuracy: 0.8480
# Epoch 5/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5716 - accuracy: 0.8467
# Epoch 6/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5437 - accuracy: 0.8440
# Epoch 7/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5163 - accuracy: 0.8480
# Epoch 8/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4898 - accuracy: 0.8493
# Epoch 9/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4657 - accuracy: 0.8533
# Epoch 10/200
# ...

# %%
# Evaluate the performance of model using the loss and predictive accuracy of the model on the test dataset.
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test, verbose=2)

print(model_loss)
print(model_accuracy)
# Out:
# 8/8 - 0s - loss: 0.0022 - accuracy: 1.0000 - 388ms/epoch - 49ms/step
# 0.0021705266553908587
# 1.0
